# %% [markdown]
# - > many complex agentic tasks involve multiple sub-tasks that can be executed simulatneously rather than one after another.
# - > this is where the parallelization pattern becomes crucial

# %% [markdown]
# ![image.png](attachment:image.png)
